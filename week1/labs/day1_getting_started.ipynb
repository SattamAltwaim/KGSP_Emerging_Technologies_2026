# %% [markdown]
# ##  **Downlaod the dataset**:
#
#  [**Download Link**](https://drive.google.com/file/d/1E82Pus9yhmCMQKnt1d6Uv2yMPSMow--6/view?usp=sharing)

# %% [markdown]
# ### **Uplaod and read the dataset**

# %% [markdown]
# ### **Modeling**
