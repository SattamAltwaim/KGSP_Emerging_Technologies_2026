# %% [markdown]
# ![KAUST Academy](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # Day 9 -- Lab 2: CNN CIFAR-10 Challenge
#
# Build and train a CNN on **CIFAR-10** from scratch with **no scaffolding**.
#
# CIFAR-10 has 60,000 colour images (32x32, 3 channels) across 10 classes: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck.
#
# Use everything you have learned.
#
# **Goal:** Achieve the highest accuracy you can on CIFAR-10. A good CNN should reach 85%+.

# %% [markdown]
# ## Imports and Setup

# %%
# Your code here

# %% [markdown]
# ---
# ## Part 1 -- Data Loading and Exploration
#
# Load CIFAR-10 using `torchvision.datasets.CIFAR10`. Inspect the shapes and visualize some samples.

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ---
# ## Part 2 -- Data Augmentation
#
# Define training transforms (with augmentation and normalization) and test transforms (normalization only). Recreate datasets and DataLoaders.

# %%
# Your code here

# %% [markdown]
# ---
# ## Part 3 -- Build the CNN
#
# Define a CNN model using `nn.Module`. Include convolutional layers, batch normalization, pooling, and dropout.

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ---
# ## Part 4 -- Training
#
# Set up loss function, optimizer, and learning rate scheduler. Write the training loop.

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Plot Training Curves

# %%
# Your code here

# %% [markdown]
# ---
# ## Part 5 -- Evaluation
#
# Report test accuracy, plot a confusion matrix, and show misclassified examples.

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ### *Contributed By: Sattam Altwaim*
